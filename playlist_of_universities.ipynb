# %%
import spotipy
import json
import webbrowser
import urllib.request
import spotipy.util as util #I imported all the documents I need{'country': 'United Kingdom', 'domains': ['f

# %%
request = urllib.request.Request("http://universities.hipolabs.com/search?country=United+Kingdom")#ASKING FOR DATA
response = urllib.request.urlopen(request)

# %%
uni = json.loads(response.read()) #DECODING and read the json document

# %%
print(uni)
# Out:
# [{'country': 'United Kingdom', 'domains': ['futureworks.ac.uk'], 'web_pages': ['https://futureworks.ac.uk/'], 'alpha_two_code': 'GB', 'name': 'Futureworks', 'state-province': None}, {'country': 'United Kingdom', 'domains': ['arts.ac.uk'], 'web_pages': ['https://www.arts.ac.uk'], 'alpha_two_code': 'GB', 'name': 'University of the Arts London', 'state-province': None}, {'country': 'United Kingdom', 'domains': ['abdn.ac.uk', 'aberdeen.ac.uk'], 'web_pages': ['http://www.abdn.ac.uk/'], 'alpha_two_code': 'GB', 'name': 'University of Aberdeen', 'state-province': None}, {'country': 'United Kingdom', 'domains': ['aber.ac.uk'], 'web_pages': ['http://www.aber.ac.uk/'], 'alpha_two_code': 'GB', 'name': 'University of Wales, Aberystwyth', 'state-province': None}, {'country': 'United Kingdom', 'domains': ['abertay.ac.uk'], 'web_pages': ['http://www.abertay.ac.uk/'], 'alpha_two_code': 'GB', 'name': 'University of Abertay Dundee', 'state-province': None}, {'country': 'United Kingdom', 'domains': ['ai
# ...

# %%
type(uni)
# Out:
# list

# %%
list_name = [] #
for data_dic in uni:
    list_name.append (data_dic['name'])
print(list_name)
# Out:
# ['Futureworks', 'University of the Arts London', 'University of Aberdeen', 'University of Wales, Aberystwyth', 'University of Abertay Dundee', 'American InterContinental University - London', 'Aga Khan University', 'Anglia Ruskin University', 'Aston University', 'The American University in London', 'University of Wales, Bangor', 'University of Bath', 'Bath Spa University', 'Birkbeck College, University of London', 'British College of Osteopathic Medicine', 'Birmingham City University', 'University of Bedfordshire', 'University of Birmingham', 'University of Bolton', 'Bournemouth University', 'University of Bradford', 'London School of Jewish Studies', 'University of Bristol', 'Oxford Brookes University', 'Brunel University Uxbridge', 'University of Brighton', 'University of Buckingham', 'Buckinghamshire New University', 'University of Cambridge', 'Camberwell College of Arts', 'Canterbury Christ Church University', 'Cardiff University', 'Chelsea College of Art and Design', 'University
# ...

# %%
#import random
#random.shuffle(uni) #make the data random
#name = uni[0]
#name

# %%
#uni_name = name["name"]

# %%
#uni_name

# %%
# open file with keys and set the path to your credentials JSON file
credentials = "spoti.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
# read the keys and assign each to a variable
# A redirect URI, or reply URL, is the location where the authorization server sends the user once the app has been 
# successfully authorized and granted an authorization code or access token.
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]
redirectURI = api_tokens["redirect"]
username = api_tokens["username"]

# %%
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public'
token = util.prompt_for_user_token(username, scope, client_id=client_id,
                           client_secret=client_secret,
                           redirect_uri=redirectURI)

# %%
sp = spotipy.Spotify(auth=token)

# %%
import random
# start a list of songs from my headline playlist
songs_for_playlist = []
# have for loop run 50 times
for keyword in range(50):
    #search for artist
    new_keyword = random.choice(list_name)
    searchResults = sp.search(q="album:" + new_keyword, type="track", limit =1)
    # if the search returns anything
    if len(searchResults['tracks']['items']) > 0:
        songs_for_playlist.append(searchResults['tracks']['items'][0]['uri'])

print(songs_for_playlist)
# Out:
# ['spotify:track:6fWtGEJaMP94O3408Gb70p', 'spotify:track:17oUefNSYx3liaIII92U3S', 'spotify:track:5l5TsSxFeGtrUIy8lITeKk', 'spotify:track:4oAi0nrW62rNBP0oGKURYN', 'spotify:track:5ClawViCxwedNbKA6JsQ9n', 'spotify:track:2NiLgKyDv4GRDxHFGhpUo3', 'spotify:track:5ofZyFDXDS0u5ZIFbdFFdF', 'spotify:track:7dUb5rOYrU7LKhrGC6bHoA', 'spotify:track:5y8lgbfprUKMMQ2Yw0V1PC', 'spotify:track:72Uvt1hUe4KN35OUKh1OuV']

# %%
#track_results = sp.search(q=uni_name, type='track', limit=50)

# %%
#tracks = track_results['tracks']['items']

# %%
#track_selection_list = []
#track_art = []

#for song in tracks:
    #track_selection_list.append(song['uri'])
    #track_art.append(song['album']['images'][0]['url'])

# %%
my_playlist = sp.user_playlist_create(user=username, name="can you guess? there is a boring guy made a boring playlist for many many universities", public=True,
                                      description="Songs for the universities")
results = sp.user_playlist_add_tracks(username, my_playlist['id'], songs_for_playlist)
print(results)
# Out:
# {'snapshot_id': 'Myw3NDBiNzgzOGExNWUyNzU5MGE3NTcxZGFhZGI1ZmZlNGY1NzY2YmM1'}

# %%
print(my_playlist)
# Out:
# {'collaborative': False, 'description': 'Songs for the universities', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/0eAoFU9d2btvvaAh9CvyyD'}, 'followers': {'href': None, 'total': 0}, 'href': 'https://api.spotify.com/v1/playlists/0eAoFU9d2btvvaAh9CvyyD', 'id': '0eAoFU9d2btvvaAh9CvyyD', 'images': [], 'name': 'can you guess? there is a boring guy made a boring playlist for many many universities', 'owner': {'display_name': 'Jia', 'external_urls': {'spotify': 'https://open.spotify.com/user/31jikkmudnewear6lgnxezylmdv4'}, 'href': 'https://api.spotify.com/v1/users/31jikkmudnewear6lgnxezylmdv4', 'id': '31jikkmudnewear6lgnxezylmdv4', 'type': 'user', 'uri': 'spotify:user:31jikkmudnewear6lgnxezylmdv4'}, 'primary_color': None, 'public': True, 'snapshot_id': 'MSxmNTY3NTNjZDg5NzRmZjY4MWI2NzBjMzlkNmIyMTNiYjBhYTEzNWUz', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/0eAoFU9d2btvvaAh9CvyyD/tracks', 'items': [], 'limit': 100, 'next': None, 'offset': 0, 'previous': None, 't
# ...

# %%
webbrowser.open(my_playlist['external_urls']['spotify'])
# Out:
# True
